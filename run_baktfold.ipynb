# %% [markdown]
# <a href="https://colab.research.google.com/github/gbouras13/baktfold/blob/dev/run_baktfold.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Batkfold
#
# [baktfold](https://github.com/gbouras13/baktfold) is a sensitive protein annotation tool for annotation across the microbial tree of life, including bacteria, archaea, MAGs, plasmids and micro-eukaryotes.
#
# baktfold uses the [ProstT5](https://github.com/mheinzinger/ProstT5) protein language model to translate hypothetical protein amino acid sequences to the 3Di token alphabet used by [Foldseek](https://github.com/steineggerlab/foldseek). Foldseek is then used to search these against a series of databases of protein structures (AFDB Clusters, SwissProt, CATH and PDB).
#
# For now, baktfold takes either the `.json` output file from [batka](https://github.com/oschwengers/bakta) or an input of amino acid sequences (in `.faa` format - these can be any protein sequences you like, not necessarily the output from bakta).
#
# Baktfold also now containers parsers to convert prokka (see Cell 6) and eukaryotic (cell 7) GenBank files to the required Bakta JSON format. If your GenBank genome annotation file is in neither format, please see [genbank_to](https://github.com/linsalrob/genbank_to) which contains a parser from generic GenBank format to JSON.
#
# If you want to annotate a bacterial genome with baktfold, you will need to run bakta first to get the `.json` file - if you are compute limited, we recommend the awesome [bakta webserver](https://bakta.computational.bio/).
#
# * **Before you start, please make sure you the runtime is T4 GPU (or any other kind of GPU if you have $$$), otherwise baktfold won't be installed properly**
# * To do this, go to the top toolbar, then to Runtime -> Change runtime type -> Hardware accelerator
#
# * To run the cells, press the play button on the left side
# * Cells 1, 2 and 3 install baktfold and downloads the databases/models.
# * Once cells 1-3 have been run, you can re-run Cell 4 (to run `baktfold run` for genomes) and/or Cell 5 (to run `baktfold proteins` for proteins) to annotate different inputs as many times as you would like
# * If you have Prokka GenBank input, please run Cell 6 before 4
# * If you have eukaryotic GenBank input, please run Cell 7 before 4

# %%
#@title 1. Install miniforge

#@markdown This cell installs miniforge

# %%bash

set -e

PYTHON_VERSION=$(python3 -c "import sys; print(f'{sys.version_info.major}.{sys.version_info.minor}')")

echo "python version ${PYTHON_VERSION}"

if [ ! -f CONDA_READY ]; then
  echo "installing miniforge"

  # miniforge 25.9.1 introduces some issue - latest as of 7 Nov 2025 - see https://github.com/gbouras13/phold/issues/106
  # issue is fixed if you use the previous release (25.3.1)
  #wget -qnc https://github.com/conda-forge/miniforge/releases/latest/download/Miniforge3-Linux-x86_64.sh
  wget -qnc https://github.com/conda-forge/miniforge/releases/download/25.3.1-0/Miniforge3-25.3.1-0-Linux-x86_64.sh
  bash Miniforge3-25.3.1-0-Linux-x86_64.sh -bfp /usr/local 2>&1 1>/dev/null
  conda config --set auto_update_conda false
  touch CONDA_READY
fi

pip install --upgrade matplotlib matplotlib-inline protobuf tiktoken

# %%
#@title 2. Install baktfold

#@markdown This cell installs baktfold. It will take a few minutes. Please be patient

BAKTFOLD_VERSION="0.1.0"

# add paths
import sys
sys.path.append("/usr/local/bin")

# Update environment variables for shell usage
import os
os.environ["PATH"] = "/usr/local/bin:" + os.environ["PATH"]

# create envs
# pharokka isn't compatible with Python 3.13 (Google Colab default)
# so it needs a separate env
from pathlib import Path
flag_file = Path("BAKTFOLD_READY")
if not flag_file.exists():
  # !conda install -y -c bioconda baktfold=={BAKTFOLD_VERSION} pytorch=*=cuda*
  # Touch the flag file
  flag_file.touch()

# %%
#@title 3. Download baktfold databases

#@markdown This cell downloads the baktfold database. It will take a few minutes. Please be patient. Perhaps go for a walk or have a coffee or tea.


# %%time

print("Downloading and processing the baktfold database. This will take 5-10 minutes. Please be patient :)")
# !baktfold install -d baktfold_db -t 8 --foldseek-gpu
# Out:
# Downloading baktfold database. This will take a few minutes. Please be patient :)
# 2026-03-19 06:39:02.531 | INFO     | baktfold:install:1780 - You have specified the baktfold_db directory to store the baktfold database and ProstT5 model
# 2026-03-19 06:39:02.531 | INFO     | baktfold:install:1792 - Checking that the Rostlab/ProstT5_fp16 ProstT5 model is available in baktfold_db
# 2026-03-19 06:39:02.531 | INFO     | baktfold.features.predict_3Di:get_T5_model:137 - Using device: cpu
# 2026-03-19 06:39:02.531 | INFO     | baktfold.features.predict_3Di:get_T5_model:143 - Loading T5 from: baktfold_db/Rostlab/ProstT5_fp16
# 2026-03-19 06:39:02.531 | INFO     | baktfold.features.predict_3Di:get_T5_model:144 - If baktfold_db/Rostlab/ProstT5_fp16 is not found, it will be downloaded
# Loading weights: 100% 196/196 [00:01<00:00, 107.96it/s]
# The tied weights mapping and config for this model specifies to tie shared.weight to encoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# T5EncoderModel LOAD REPORT from: Rostlab/ProstT5_fp16
# Key            | Status     |  |
# ---------------+------------+--+-
# lm_head.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights: 100% 196/196 [00:01<00:00, 185.92it/s]
# The tied weights mapping and config for this model specifies to tie shared.weight to encoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# T5EncoderModel LOAD REPORT from: Rostlab/ProstT5_fp16
# Key            | Status     |  |
# ---------------+------------+--+-
# lm_head.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 2026-03-19 06:39:29.666 | INFO     | baktfold.features.predict_3Di:get_T5_model:188 - Rostlab/ProstT5_fp16 loaded
# 2026-03-19 06:39:29.842 | INFO     | baktfold:install:1803 - ProstT5 model downloaded
# 2026-03-19 06:39:29.843 | INFO     | baktfold.databases.db:install_database:167 - Checking baktfold database installation in baktfold_db.
# 2026-03-19 06:39:29.843 | WARNING  | baktfold.databases.db:check_db_installation:445 - baktfold Database file baktfold_db/AFDBClusters is missing
# 2026-03-19 06:39:29.843 | WARNING  | baktfold.databases.db:check_db_installation:454 - baktfold Foldseek-GPU Database file baktfold_db/AFDBClusters_gpu is missing
# 2026-03-19 06:39:29.843 | INFO     | baktfold.databases.db:install_database:172 - Some baktfold databases files are missing
# 2026-03-19 06:39:29.843 | INFO     | baktfold.databases.db:install_database:176 - Downloading baktfold DB from https://zenodo.org/records/17347516/files/baktfold_db.tar.gz?download=1
# 2026-03-19 06:39:29.843 | INFO     | baktfold.databases.db:install_database:185 - Downloading from HuggingFace
# baktfold_db.tar.gz: 100% 8.75G/8.75G [01:21<00:00, 108MB/s]
# 2026-03-19 06:40:51.155 | INFO     | baktfold.databases.db:download:255 - Tarball saved to baktfold_db/baktfold_db.tar.gz
# 2026-03-19 06:41:27.169 | INFO     | baktfold.databases.db:install_database:199 - baktfold database file download OK: b1eba2ac1a35e9c34b125887cb4aaf51
# 2026-03-19 06:41:27.169 | INFO     | baktfold.databases.db:install_database:205 - Extracting baktfold database tarball: file=baktfold_db/baktfold_db.tar.gz, output=baktfold_db
# 2026-03-19 06:43:47.049 | INFO     | baktfold.databases.db:install_database:215 - Some baktfold database files compatible with Foldseek-GPU are missing
# 2026-03-19 06:43:47.073 | INFO     | baktfold.databases.db:install_database:216 - Creating them
# 2026-03-19 06:43:47.077 | INFO     | baktfold.utils.external_tools:run:128 - Started running foldseek makepaddedseqdb baktfold_db/AFDBClusters baktfold_db/AFDBClusters_gpu ...
# 2026-03-19 06:45:46.415 | INFO     | baktfold.utils.external_tools:run:130 - Done running foldseek makepaddedseqdb baktfold_db/AFDBClusters baktfold_db/AFDBClusters_gpu
# 2026-03-19 06:45:46.422 | INFO     | baktfold.utils.external_tools:run:128 - Started running foldseek makepaddedseqdb baktfold_db/pdb baktfold_db/pdb_gpu ...
# 2026-03-19 06:45:50.952 | INFO     | baktfold.utils.external_tools:run:130 - Done running foldseek makepaddedseqdb baktfold_db/pdb baktfold_db/pdb_gpu
# 2026-03-19 06:45:50.952 | INFO     | baktfold.utils.external_tools:run:128 - Started running foldseek makepaddedseqdb baktfold_db/cath baktfold_db/cath_gpu ...
# 2026-03-19 06:45:53.738 | INFO     | baktfold.utils.external_tools:run:130 - Done running foldseek makepaddedseqdb baktfold_db/cath baktfold_db/cath_gpu
# 2026-03-19 06:45:53.739 | INFO     | baktfold.utils.external_tools:run:128 - Started running foldseek makepaddedseqdb baktfold_db/swissprot baktfold_db/swissprot_gpu ...
# 2026-03-19 06:46:34.457 | INFO     | baktfold.utils.external_tools:run:130 - Done running foldseek makepaddedseqdb baktfold_db/swissprot baktfold_db/swissprot_gpu
# 2026-03-19 06:46:34.457 | INFO     | baktfold.databases.db:install_database:219 - Database download and processing complete
# CPU times: user 796 ms, sys: 99.3 ms, total: 895 ms
# Wall time: 7min 45s

# %%
#@title 4. baktfold run (bakta json input)

#@markdown First, upload your bakta json file.

#@markdown Click on the folder icon to the left and use the file upload button.

#@markdown Once it is uploaded, write the file name in the INPUT_FILE field on the right.

#@markdown Then provide a directory for baktfold's output using BAKTFOLD_OUT_DIR.
#@markdown The default is 'output_baktfold'.

#@markdown You can also provide a prefix for your output files with BAKTFOLD_PREFIX.
#@markdown If you provide nothing it will default to 'baktfold'.

#@markdown You can click FORCE to overwrite the output directory.
#@markdown This may be useful if your earlier baktfold run has crashed for whatever reason.

#@markdown You can click EUK if your input JSON file is on a eukaryotic genome to ensure Baktfold parses it correctly.

#@markdown The results of Baktfold will be in the folder icon on the left hand panel.
#@markdown Additionally, it will be zipped so you can download the whole directory.

#@markdown The file to download is BAKTFOLD_OUT_DIR.zip, where BAKTFOLD_OUT_DIR is what you provided

#@markdown If you do not see the output directory,
#@markdown refresh the window by either clicking the folder with the refresh icon below "Files"
#@markdown or double click and select "Refresh".


# %%time
import os
import sys
import subprocess
import zipfile
INPUT_FILE = '' #@param {type:"string"}

if os.path.exists(INPUT_FILE):
    print(f"Input file {INPUT_FILE} exists")
else:
    print(f"Error: File {INPUT_FILE} does not exist")
    print(f"Please check the spelling and that you have uploaded it correctly")
    sys.exit(1)

BAKTFOLD_OUT_DIR = 'output_baktfold'  #@param {type:"string"}
BAKTFOLD_PREFIX = 'baktfold'  #@param {type:"string"}
FORCE = True  #@param {type:"boolean"}
EUK = False  #@param {type:"boolean"}

# Construct the command
command = (
    f'baktfold run -d baktfold_db -i {INPUT_FILE} -t 4 '
    f'-o {BAKTFOLD_OUT_DIR} -p {BAKTFOLD_PREFIX} --foldseek-gpu'
)

if FORCE is True:
  command = f"{command} -f"

if EUK is True:
  command = f"{command} --euk"

# Execute the command
try:
    print("Running baktfold")
    subprocess.run(command, shell=True, check=True)
    print("baktfold completed successfully.")
    print(f"Your output is in {BAKTFOLD_OUT_DIR}.")
    print(f"Zipping the output directory so you can download it all in one go.")

    zip_filename = f"{BAKTFOLD_OUT_DIR}.zip"

    # Zip the contents of the output directory
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(BAKTFOLD_OUT_DIR):
            for file in files:
                zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), BAKTFOLD_OUT_DIR))
    print(f"Output directory has been zipped to {zip_filename}")


except subprocess.CalledProcessError as e:
    print(f"Error occurred: {e}")
# Out:
# Input file baktfold_euk.json exists
# Running baktfold

# %%
#@title 5. baktfold proteins (protein input)

#@markdown First, upload your file containing protein amino acid sequences (`.faa` format).

#@markdown Click on the folder icon to the left and use the file upload button.

#@markdown Once it is uploaded, write the file name in the INPUT_FILE field on the right.

#@markdown Then provide a directory for baktfold's output using BAKTFOLD_PROTEINS_OUT_DIR.
#@markdown The default is 'output_baktfold_proteins'.

#@markdown You can also provide a prefix for your output files with BAKTFOLD_PREFIX.
#@markdown If you provide nothing it will default to 'baktfold'.


#@markdown You can click FORCE to overwrite the output directory.
#@markdown This may be useful if your earlier baktfold run has crashed for whatever reason.

#@markdown The results of Baktfold will be in the folder icon on the left hand panel.
#@markdown Additionally, it will be zipped so you can download the whole directory.

#@markdown The file to download is BAKTFOLD_PROTEINS_OUT_DIR.zip, where BAKTFOLD_PROTEINS_OUT_DIR is what you provided

#@markdown If you do not see the output directory,
#@markdown refresh the window by either clicking the folder with the refresh icon below "Files"
#@markdown or double click and select "Refresh".



# %%time
import os
import sys
import subprocess
import zipfile
INPUT_FILE = '' #@param {type:"string"}

if os.path.exists(INPUT_FILE):
    print(f"Input file {INPUT_FILE} exists")
else:
    print(f"Error: File {INPUT_FILE} does not exist")
    print(f"Please check the spelling and that you have uploaded it correctly")
    sys.exit(1)

BAKTFOLD_PROTEINS_OUT_DIR = 'output_baktfold_proteins'  #@param {type:"string"}
BAKTFOLD_PREFIX = 'baktfold'  #@param {type:"string"}
FORCE = True  #@param {type:"boolean"}


# Construct the command
command = (
    f'baktfold proteins -d baktfold_db -i {INPUT_FILE} -t 4 '
    f'-o {BAKTFOLD_PROTEINS_OUT_DIR} -p {BAKTFOLD_PREFIX} --foldseek-gpu'
)

if FORCE is True:
  command = f"{command} -f"

# Execute the command
try:
    print("Running baktfold")
    subprocess.run(command, shell=True, check=True)
    print("baktfold completed successfully.")
    print(f"Your output is in {BAKTFOLD_PROTEINS_OUT_DIR}.")
    print(f"Zipping the output directory so you can download it all in one go.")

    zip_filename = f"{BAKTFOLD_PROTEINS_OUT_DIR}.zip"

    # Zip the contents of the output directory
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(BAKTFOLD_PROTEINS_OUT_DIR):
            for file in files:
                zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), BAKTFOLD_PROTEINS_OUT_DIR))
    print(f"Output directory has been zipped to {zip_filename}")


except subprocess.CalledProcessError as e:
    print(f"Error occurred: {e}")
# Out:
# Input file assembly.hypotheticals.faa exists
# Running baktfold
# baktfold completed successfully.
# Your output is in output_baktfold_proteins.
# Zipping the output directory so you can download it all in one go.
# Output directory has been zipped to output_baktfold_proteins.zip
# CPU times: user 8.73 ms, sys: 8.25 ms, total: 17 ms
# Wall time: 1min 52s

# %%
#@title 6. baktfold convert-prokka (Prokka GenBank input)

#@markdown Only use this if you would like to run Baktfold on Prokka output (then run cell 4)

#@markdown First, upload your Prokka GBK file.

#@markdown Click on the folder icon to the left and use the file upload button.

#@markdown Once it is uploaded, write the file name in the INPUT_FILE field on the right.

#@markdown Then provide an output file name where your genome will be processed into the Bakta JSON format.

#@markdown The file to download is BAKTFOLD_PREFIX.json, where BAKTFOLD_PREFIX is what you provided

#@markdown If you do not see the output,
#@markdown refresh the window by either clicking the folder with the refresh icon below "Files"
#@markdown or double click and select "Refresh".


# %%time
import os
import sys
import subprocess
import zipfile
INPUT_FILE = '' #@param {type:"string"}

if os.path.exists(INPUT_FILE):
    print(f"Input file {INPUT_FILE} exists")
else:
    print(f"Error: File {INPUT_FILE} does not exist")
    print(f"Please check the spelling and that you have uploaded it correctly")
    sys.exit(1)

BAKTFOLD_PREFIX = 'baktfold'  #@param {type:"string"}
FORCE = True  #@param {type:"boolean"}
BAKTFOLD_OUT_FILE = f"{BAKTFOLD_PREFIX}.json"

# Construct the command
command = (
    f'baktfold convert-prokka  -i {INPUT_FILE} '
    f'-o {BAKTFOLD_OUT_FILE}'
)

if FORCE is True:
  command = f"{command} -f"

# Execute the command
try:
    print("Running baktfold convert-prokka")
    subprocess.run(command, shell=True, check=True)
    print("baktfold completed successfully.")
    print(f"Your output is {BAKTFOLD_OUT_FILE}.")

except subprocess.CalledProcessError as e:
    print(f"Error occurred: {e}")
# Out:
# Input file PROKKA_02192026.gbk exists
# Running baktfold convert-prokka
# baktfold completed successfully.
# Your output is baktfold.json.
# CPU times: user 2.14 ms, sys: 0 ns, total: 2.14 ms
# Wall time: 7.02 s

# %%
#@title 7. baktfold convert-euk (Eukaryotic GenBank input)

#@markdown Only use this if you would like to run Baktfold on eukaryotic GenBank files (then run cell 4 with the euk flag clicked to be True)

#@markdown First, upload your Genbank format file.

#@markdown Click on the folder icon to the left and use the file upload button.

#@markdown Once it is uploaded, write the file name in the INPUT_FILE field on the right.

#@markdown Then provide an output file name where your genome will be processed into the Bakta JSON format.

#@markdown The file to download is BAKTFOLD_PREFIX.json, where BAKTFOLD_PREFIX is what you provided

#@markdown If you do not see the output,
#@markdown refresh the window by either clicking the folder with the refresh icon below "Files"
#@markdown or double click and select "Refresh".


# %%time
import os
import sys
import subprocess
import zipfile
INPUT_FILE = '' #@param {type:"string"}

if os.path.exists(INPUT_FILE):
    print(f"Input file {INPUT_FILE} exists")
else:
    print(f"Error: File {INPUT_FILE} does not exist")
    print(f"Please check the spelling and that you have uploaded it correctly")
    sys.exit(1)

BAKTFOLD_PREFIX = 'baktfold_euk'  #@param {type:"string"}
FORCE = True  #@param {type:"boolean"}
BAKTFOLD_OUT_FILE = f"{BAKTFOLD_PREFIX}.json"

# Construct the command
command = (
    f'baktfold convert-euk  -i {INPUT_FILE} '
    f'-o {BAKTFOLD_OUT_FILE}'
)

if FORCE is True:
  command = f"{command} -f"

# Execute the command
try:
    print("Running baktfold convert-euk")
    subprocess.run(command, shell=True, check=True)
    print("baktfold completed successfully.")
    print(f"Your output is {BAKTFOLD_OUT_FILE}.")

except subprocess.CalledProcessError as e:
    print(f"Error occurred: {e}")
# Out:
# Input file protist.gbk.gz exists
# Running baktfold convert-euk
# baktfold completed successfully.
# Your output is baktfold_euk.json.
# CPU times: user 2.23 ms, sys: 932 µs, total: 3.16 ms
# Wall time: 12.4 s
